# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
import matplotlib.pyplot as plt
import datetime as dt

# %%
df=pd.read_csv('C:/Users/yashw/Downloads/New folder/IPL Matches 2008-2020.csv')

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df['result'].value_counts()
# Out:
# wickets    435
# runs       364
# tie         13
# Name: result, dtype: int64

# %%
np.where(df['result']=='tie')
# Out:
# (array([ 66, 130, 328, 341, 416, 476, 610, 705, 746, 757, 776, 781, 811],
#        dtype=int64),)

# %%
qe=df['result'].value_counts()
qe.plot.pie(autopct="%.1f%%");

# %%
df=df.drop(columns='method')

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# id                 0.000000
# city               1.593137
# date               0.000000
# player_of_match    0.490196
# venue              0.000000
# neutral_venue      0.000000
# team1              0.000000
# team2              0.000000
# toss_winner        0.000000
# toss_decision      0.000000
# winner             0.490196
# result             0.490196
# result_margin      2.083333
# eliminator         0.490196
# umpire1            0.000000
# umpire2            0.000000
# dtype: float64

# %%
df.isnull().sum()
# Out:
# id                  0
# city               13
# date                0
# player_of_match     4
# venue               0
# neutral_venue       0
# team1               0
# team2               0
# toss_winner         0
# toss_decision       0
# winner              4
# result              4
# result_margin      17
# eliminator          4
# umpire1             0
# umpire2             0
# dtype: int64

# %%
df['team2'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Royal Challengers Bangalore', 'Deccan Chargers',
#        'Kings XI Punjab', 'Delhi Daredevils', 'Mumbai Indians',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals'], dtype=object)

# %%
df['team2']=df['team2'].apply(lambda x:'Rising Pune Supergiant' if(x=='Rising Pune Supergiants') else x)

# %%
for i in df['team1'].unique():
    print(i)
# Out:
# Royal Challengers Bangalore
# Kings XI Punjab
# Delhi Daredevils
# Mumbai Indians
# Kolkata Knight Riders
# Rajasthan Royals
# Deccan Chargers
# Chennai Super Kings
# Kochi Tuskers Kerala
# Pune Warriors
# Sunrisers Hyderabad
# Gujarat Lions
# Rising Pune Supergiants
# Rising Pune Supergiant
# Delhi Capitals

# %%
df['team1']=df['team1'].apply(lambda x:'Rising Pune Supergiant' if(x=='Rising Pune Supergiants') else x)

# %%
df['eliminator'].value_counts()
# Out:
# N    799
# Y     13
# Name: eliminator, dtype: int64

# %%
df.iloc[np.where(df['result']=='tie')].shape
# Out:
# (13, 16)

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df['result'].unique()
# Out:
# array(['runs', 'wickets', 'tie', nan], dtype=object)

# %%
df['result_margin'].value_counts()
# Out:
# 6.0      95
# 7.0      94
# 5.0      85
# 8.0      67
# 4.0      53
#          ..
# 102.0     1
# 42.0      1
# 66.0      1
# 47.0      1
# 98.0      1
# Name: result_margin, Length: 91, dtype: int64

# %%
df.iloc[np.where(df['result']=='tie')]
# Out:
#           id       city        date player_of_match  \
# 66    392190  Cape Town  2009-04-23       YK Pathan
# 130   419121    Chennai  2010-03-21        J Theron
# 328   598004  Hyderabad  2013-04-07       GH Vihari
# 341   598017  Bangalore  2013-04-16         V Kohli
# 416   729315  Abu Dhabi  2014-04-29     JP Faulkner
# 476   829741  Ahmedabad  2015-04-21        SE Marsh
# 610  1082625     Rajkot  2017-04-29       KH Pandya
# 705  1175365      Delhi  2019-03-30         PP Shaw
# 746  1178426     Mumbai  2019-05-02       JJ Bumrah
# 757  1216493      Dubai  2020-09-20      MP Stoinis
# 776  1216512  Abu Dhabi  2020-10-18     LH Ferguson
# 781  1216517      Dubai  2020-10-18        KL Rahul
# 811  1216547      Dubai  2020-09-28  AB de Villiers
#
#                                          venue  neutral_venue  \
# 66                                    Newlands              1
# 130            MA Chidambaram Stadium, Chepauk              0
# ...

# %%
ac=df[['umpire1']].value_counts()

# %%
df[['winner','result','eliminator','result_margin']].head(40)
# Out:
#                          winner   result eliminator  result_margin
# 0         Kolkata Knight Riders     runs          N          140.0
# 1           Chennai Super Kings     runs          N           33.0
# 2              Delhi Daredevils  wickets          N            9.0
# 3   Royal Challengers Bangalore  wickets          N            5.0
# 4         Kolkata Knight Riders  wickets          N            5.0
# 5              Rajasthan Royals  wickets          N            6.0
# 6              Delhi Daredevils  wickets          N            9.0
# 7           Chennai Super Kings     runs          N            6.0
# 8              Rajasthan Royals  wickets          N            3.0
# 9               Kings XI Punjab     runs          N           66.0
# 10             Rajasthan Royals  wickets          N            7.0
# 11          Chennai Super Kings  wickets          N            9.0
# 12              Deccan Chargers  wickets          N           10.0
# ...

# %%
df.iloc[np.where(df['eliminator']=='Y')]
# Out:
#           id       city        date player_of_match  \
# 66    392190  Cape Town  2009-04-23       YK Pathan
# 130   419121    Chennai  2010-03-21        J Theron
# 328   598004  Hyderabad  2013-04-07       GH Vihari
# 341   598017  Bangalore  2013-04-16         V Kohli
# 416   729315  Abu Dhabi  2014-04-29     JP Faulkner
# 476   829741  Ahmedabad  2015-04-21        SE Marsh
# 610  1082625     Rajkot  2017-04-29       KH Pandya
# 705  1175365      Delhi  2019-03-30         PP Shaw
# 746  1178426     Mumbai  2019-05-02       JJ Bumrah
# 757  1216493      Dubai  2020-09-20      MP Stoinis
# 776  1216512  Abu Dhabi  2020-10-18     LH Ferguson
# 781  1216517      Dubai  2020-10-18        KL Rahul
# 811  1216547      Dubai  2020-09-28  AB de Villiers
#
#                                          venue  neutral_venue  \
# 66                                    Newlands              1
# 130            MA Chidambaram Stadium, Chepauk              0
# ...

# %%
df.isnull().sum()
# Out:
# id                  0
# city               13
# date                0
# player_of_match     4
# venue               0
# neutral_venue       0
# team1               0
# team2               0
# toss_winner         0
# toss_decision       0
# winner              4
# result              4
# result_margin      17
# eliminator          4
# umpire1             0
# umpire2             0
# dtype: int64

# %%
df['result_margin']= df['result_margin'].fillna('Not Available')

# %%
df.iloc[np.where(df['result']=='tie')]
# Out:
#           id       city        date player_of_match  \
# 66    392190  Cape Town  2009-04-23       YK Pathan
# 130   419121    Chennai  2010-03-21        J Theron
# 328   598004  Hyderabad  2013-04-07       GH Vihari
# 341   598017  Bangalore  2013-04-16         V Kohli
# 416   729315  Abu Dhabi  2014-04-29     JP Faulkner
# 476   829741  Ahmedabad  2015-04-21        SE Marsh
# 610  1082625     Rajkot  2017-04-29       KH Pandya
# 705  1175365      Delhi  2019-03-30         PP Shaw
# 746  1178426     Mumbai  2019-05-02       JJ Bumrah
# 757  1216493      Dubai  2020-09-20      MP Stoinis
# 776  1216512  Abu Dhabi  2020-10-18     LH Ferguson
# 781  1216517      Dubai  2020-10-18        KL Rahul
# 811  1216547      Dubai  2020-09-28  AB de Villiers
#
#                                          venue  neutral_venue  \
# 66                                    Newlands              1
# 130            MA Chidambaram Stadium, Chepauk              0
# ...

# %%
df['result_margin'].value_counts()
# Out:
# 6.0      95
# 7.0      94
# 5.0      85
# 8.0      67
# 4.0      53
#          ..
# 69.0      1
# 72.0      1
# 74.0      1
# 75.0      1
# 146.0     1
# Name: result_margin, Length: 92, dtype: int64

# %%
df['city']=df['city'].fillna(df['city'].mode()[0])

# %%
df['result']=df['result'].fillna(df['result'].mode()[0])

# %%
df['result'].unique()
# Out:
# array(['runs', 'wickets', 'tie'], dtype=object)

# %%
df.isnull().sum()
# Out:
# id                 0
# city               0
# date               0
# player_of_match    4
# venue              0
# neutral_venue      0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# winner             4
# result             0
# result_margin      0
# eliminator         4
# umpire1            0
# umpire2            0
# dtype: int64

# %%
df.groupby(['result','eliminator'])['result_margin'].value_counts()
# Out:
# result   eliminator  result_margin
# runs     N           10.0             13
#                      14.0             13
#                      4.0              11
#                      1.0              10
#                      7.0              10
#                                       ..
# wickets  N           9.0              39
#                      3.0              18
#                      10.0             14
#                      2.0               6
#                      1.0               3
# Name: result_margin, Length: 102, dtype: int64

# %%
df['eliminator']=df['eliminator'].fillna(df['eliminator'].mode()[0])

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df['year']=df['date'].dt.year

# %%
y8=df.iloc[np.where(df['year']==2008)]
plt.xticks(rotation=90)
sns.set(rc = {'figure.figsize':(15,8)})
sns.histplot(y8['umpire1'])
# Out:
# <AxesSubplot:xlabel='umpire1', ylabel='Count'>

# %%
y9=df.iloc[np.where(df['year']==2009)]
plt.xticks(rotation=90)
sns.set(rc = {'figure.figsize':(15,8)})
sns.histplot(y9['umpire1'])
# Out:
# <AxesSubplot:xlabel='umpire1', ylabel='Count'>

# %%
y10=df.iloc[np.where(df['year']==2010)]
plt.xticks(rotation=90)
sns.set(rc = {'figure.figsize':(15,8)})
sns.histplot(y10['umpire1'])
# Out:
# <AxesSubplot:xlabel='umpire1', ylabel='Count'>

# %%
y11=df.iloc[np.where(df['year']==2011)]
plt.xticks(rotation=90)
sns.set(rc = {'figure.figsize':(15,8)})
sns.histplot(y11['umpire1'])
# Out:
# <AxesSubplot:xlabel='umpire1', ylabel='Count'>

# %%
y12=df.iloc[np.where(df['year']==2012)]
plt.xticks(rotation=90)
sns.set(rc = {'figure.figsize':(15,8)})
sns.histplot(y12['umpire1'])
# Out:
# <AxesSubplot:xlabel='umpire1', ylabel='Count'>

# %%
y13=df.iloc[np.where(df['year']==2013)]
plt.xticks(rotation=90)
sns.set(rc = {'figure.figsize':(15,8)})
sns.histplot(y13['umpire1'])
# Out:
# <AxesSubplot:xlabel='umpire1', ylabel='Count'>

# %%
y14=df.iloc[np.where(df['year']==2014)]
plt.xticks(rotation=90)
sns.set(rc = {'figure.figsize':(15,8)})
sns.histplot(y14['umpire1'])
# Out:
# <AxesSubplot:xlabel='umpire1', ylabel='Count'>

# %%
y15=df.iloc[np.where(df['year']==2015)]
plt.xticks(rotation=90)
sns.set(rc = {'figure.figsize':(15,8)})
sns.histplot(y15['umpire1'])
# Out:
# <AxesSubplot:xlabel='umpire1', ylabel='Count'>

# %%
y16=df.iloc[np.where(df['year']==2016)]
plt.xticks(rotation=90)
sns.set(rc = {'figure.figsize':(15,8)})
sns.histplot(y16['umpire1'])
# Out:
# <AxesSubplot:xlabel='umpire1', ylabel='Count'>

# %%
y17=df.iloc[np.where(df['year']==2017)]
plt.xticks(rotation=90)
sns.set(rc = {'figure.figsize':(15,8)})
sns.histplot(y17['umpire1'])
# Out:
# <AxesSubplot:xlabel='umpire1', ylabel='Count'>

# %%
y18=df.iloc[np.where(df['year']==2018)]
plt.xticks(rotation=90)
sns.set(rc = {'figure.figsize':(15,8)})
sns.histplot(y18['umpire1'])
# Out:
# <AxesSubplot:xlabel='umpire1', ylabel='Count'>

# %%
y19=df.iloc[np.where(df['year']==2019)]
plt.xticks(rotation=90)
sns.set(rc = {'figure.figsize':(15,8)})
sns.histplot(y19['umpire1'])
# Out:
# <AxesSubplot:xlabel='umpire1', ylabel='Count'>

# %%
y20=df.iloc[np.where(df['year']==2020)]
plt.xticks(rotation=90)
sns.set(rc = {'figure.figsize':(15,8)})
sns.histplot(y20['umpire1'])
# Out:
# <AxesSubplot:xlabel='umpire1', ylabel='Count'>

# %%
df['umpire1'].value_counts()
# Out:
# HDPK Dharmasena          78
# AK Chaudhary             56
# Asad Rauf                51
# M Erasmus                40
# Aleem Dar                38
# BF Bowden                37
# S Ravi                   37
# CB Gaffaney              34
# BR Doctrove              34
# KN Ananthapadmanabhan    33
# AY Dandekar              28
# C Shamshuddin            22
# NJ Llong                 21
# RE Koertzen              20
# Nitin Menon              20
# S Asnani                 19
# VA Kulkarni              19
# JD Cloete                16
# BNJ Oxenford             16
# A Nand Kishore           14
# YC Barde                 14
# BG Jerling               13
# RK Illingworth           13
# SS Hazare                11
# S Das                    10
# K Hariharan              10
# MR Benson                10
# DJ Harper                 9
# CK Nandan                 8
# UV Gandhe                 8
# IL Howell                 7
# GAV Baxter                7
# RM Deshpande              7
# ...

# %%
df
# Out:
#           id        city       date player_of_match  \
# 0     335982   Bangalore 2008-04-18     BB McCullum
# 1     335983  Chandigarh 2008-04-19      MEK Hussey
# 2     335984       Delhi 2008-04-19     MF Maharoof
# 3     335985      Mumbai 2008-04-20      MV Boucher
# 4     335986     Kolkata 2008-04-20       DJ Hussey
# ..       ...         ...        ...             ...
# 811  1216547       Dubai 2020-09-28  AB de Villiers
# 812  1237177       Dubai 2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi 2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi 2020-11-08      MP Stoinis
# 815  1237181       Dubai 2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df=df.dropna(axis=0)

# %%
df.iloc[np.where(df['team1']=='Royal Challengers Bangalore')].shape
# Out:
# (105, 17)

# %%
df.iloc[np.where(df['team2']=='Royal Challengers Bangalore')].shape
# Out:
# (87, 17)

# %%
# total number of team we have in out IPL
df['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiant', 'Delhi Capitals'],
#       dtype=object)

# %%
x=df['winner'].value_counts()# total matches(in Percentage) won by each team

# %%
x.plot.pie(autopct="%.1f%%",figsize=(20,20));

# %%
df['umpire1'].unique()
# Out:
# array(['Asad Rauf', 'MR Benson', 'Aleem Dar', 'SJ Davis', 'BF Bowden',
#        'IL Howell', 'DJ Harper', 'RE Koertzen', 'BR Doctrove',
#        'AV Jayaprakash', 'BG Jerling', 'M Erasmus', 'HDPK Dharmasena',
#        'S Asnani', 'GAV Baxter', 'SS Hazare', 'K Hariharan', 'SL Shastri',
#        'SK Tarapore', 'S Ravi', 'SJA Taufel', 'S Das', 'AM Saheba',
#        'PR Reiffel', 'JD Cloete', 'AK Chaudhary', 'VA Kulkarni',
#        'BNJ Oxenford', 'CK Nandan', 'C Shamshuddin', 'NJ Llong',
#        'RK Illingworth', 'RM Deshpande', 'K Srinath', 'SD Fry',
#        'CB Gaffaney', 'PG Pathak', 'Nitin Menon', 'K Bharatan',
#        'AY Dandekar', 'KN Ananthapadmanabhan', 'A Nand Kishore',
#        'A Deshmukh', 'YC Barde', 'RJ Tucker', 'VK Sharma', 'UV Gandhe',
#        'IJ Gould'], dtype=object)

# %%
# every team vs other team and how many matches each team has won
df.groupby(['team1','team2','result'])['winner'].value_counts()
# Out:
# team1                team2                        result   winner
# Chennai Super Kings  Deccan Chargers              runs     Chennai Super Kings            4
#                                                            Deccan Chargers                1
#                                                   wickets  Deccan Chargers                2
#                      Delhi Capitals               runs     Chennai Super Kings            1
#                                                   wickets  Chennai Super Kings            1
#                                                                                          ..
# Sunrisers Hyderabad  Rising Pune Supergiant       runs     Rising Pune Supergiants        1
#                      Royal Challengers Bangalore  runs     Sunrisers Hyderabad            4
#                                                   tie      Sunrisers Hyderabad            1
# ...

# %%
rcb1=df.iloc[np.where(df['team1']=='Royal Challengers Bangalore')]

# %%
rcb2=df.iloc[np.where(df['team2']=='Royal Challengers Bangalore')]

# %%
dfrcb=pd.concat([rcb1,rcb2],axis=0)

# %%
dfrcb.shape # rcb has played 192 matches
# Out:
# (192, 17)

# %% [markdown]
# RCB INSIGHTS

# %%
# insight 1
# matches rcb won and no. of matches rcb has been defeaed by other team
dfrcb['winner'].value_counts()
# Out:
# Royal Challengers Bangalore    91
# Mumbai Indians                 17
# Chennai Super Kings            16
# Kings XI Punjab                14
# Kolkata Knight Riders          14
# Sunrisers Hyderabad            10
# Rajasthan Royals               10
# Delhi Daredevils                6
# Deccan Chargers                 6
# Delhi Capitals                  4
# Rising Pune Supergiant          2
# Gujarat Lions                   2
# Name: winner, dtype: int64

# %%
# insight 2
# venues of matches played by rcb with their dates
dfrcb.groupby(['city','date'])['venue'].value_counts()
# Out:
# city       date        venue
# Abu Dhabi  2014-04-26  Sheikh Zayed Stadium                  1
#            2020-10-03  Sheikh Zayed Stadium                  1
#            2020-10-21  Sheikh Zayed Stadium                  1
#            2020-10-28  Sheikh Zayed Stadium                  1
#            2020-11-02  Sheikh Zayed Stadium                  1
#                                                             ..
# Ranchi     2014-05-18  JSCA International Stadium Complex    1
#            2015-05-22  JSCA International Stadium Complex    1
# Sharjah    2020-10-12  Sharjah Cricket Stadium               1
#            2020-10-15  Sharjah Cricket Stadium               1
#            2020-10-31  Sharjah Cricket Stadium               1
# Name: venue, Length: 192, dtype: int64

# %%
# insight 3
# Teams and their no. of match won
dfrcb.groupby(['team1','team2'])['winner'].value_counts()
# Out:
# team1                        team2                        winner
# Chennai Super Kings          Royal Challengers Bangalore  Chennai Super Kings             9
#                                                           Royal Challengers Bangalore     2
# Deccan Chargers              Royal Challengers Bangalore  Deccan Chargers                 3
#                                                           Royal Challengers Bangalore     1
# Delhi Capitals               Royal Challengers Bangalore  Delhi Capitals                  2
# Delhi Daredevils             Royal Challengers Bangalore  Royal Challengers Bangalore     8
#                                                           Delhi Daredevils                2
# Gujarat Lions                Royal Challengers Bangalore  Royal Challengers Bangalore     2
#                                                           Gujarat Lions                   1
# ...

# %%
# insight 4
dfrcb['venue'].value_counts()
# Out:
# M Chinnaswamy Stadium                                   59
# M.Chinnaswamy Stadium                                   14
# Wankhede Stadium                                        10
# Rajiv Gandhi International Stadium, Uppal               10
# Eden Gardens                                            10
# MA Chidambaram Stadium, Chepauk                          9
# Feroz Shah Kotla                                         9
# Dubai International Cricket Stadium                      9
# Sawai Mansingh Stadium                                   7
# Sheikh Zayed Stadium                                     6
# Sharjah Cricket Stadium                                  5
# Punjab Cricket Association Stadium, Mohali               5
# New Wanderers Stadium                                    4
# Kingsmead                                                4
# Maharashtra Cricket Association Stadium                  4
# St George's Park                                         3
# ...

# %%
a=dfrcb.iloc[np.where(dfrcb['winner']=='Royal Challengers Bangalore')]

# %%
a.groupby(['toss_winner'])['toss_decision'].value_counts()
# Out:
# toss_winner                  toss_decision
# Chennai Super Kings          field             3
#                              bat               2
# Deccan Chargers              bat               2
#                              field             1
# Delhi Daredevils             field             4
#                              bat               1
# Gujarat Lions                field             2
# Kings XI Punjab              field             5
#                              bat               2
# Kochi Tuskers Kerala         bat               2
# Kolkata Knight Riders        bat               2
#                              field             1
# Mumbai Indians               field             4
#                              bat               3
# Pune Warriors                field             3
#                              bat               1
# Rajasthan Royals             bat               3
#                              field             1
# ...

# %%
df[df['result']=='tie']
# Out:
#           id       city       date player_of_match  \
# 66    392190  Cape Town 2009-04-23       YK Pathan
# 130   419121    Chennai 2010-03-21        J Theron
# 328   598004  Hyderabad 2013-04-07       GH Vihari
# 341   598017  Bangalore 2013-04-16         V Kohli
# 416   729315  Abu Dhabi 2014-04-29     JP Faulkner
# 476   829741  Ahmedabad 2015-04-21        SE Marsh
# 610  1082625     Rajkot 2017-04-29       KH Pandya
# 705  1175365      Delhi 2019-03-30         PP Shaw
# 746  1178426     Mumbai 2019-05-02       JJ Bumrah
# 757  1216493      Dubai 2020-09-20      MP Stoinis
# 776  1216512  Abu Dhabi 2020-10-18     LH Ferguson
# 781  1216517      Dubai 2020-10-18        KL Rahul
# 811  1216547      Dubai 2020-09-28  AB de Villiers
#
#                                          venue  neutral_venue  \
# 66                                    Newlands              1
# 130            MA Chidambaram Stadium, Chepauk              0
# ...

# %%
# insight 5
# how rcb won from other team accordin to result
a.groupby(['team1','team2','result','result_margin'])['result'].value_counts()
# Out:
# team1                        team2                        result   result_margin  result
# Chennai Super Kings          Royal Challengers Bangalore  runs     14.0           runs       1
#                                                           wickets  5.0            wickets    1
# Deccan Chargers              Royal Challengers Bangalore  wickets  5.0            wickets    1
# Delhi Daredevils             Royal Challengers Bangalore  runs     4.0            runs       1
#                                                                    10.0           runs       1
#                                                                                             ..
# Royal Challengers Bangalore  Sunrisers Hyderabad          runs     14.0           runs       1
#                                                                    45.0           runs       1
#                                                           wickets  4.0            wickets    2
# ...

# %%
# insight 6
# most of the matches rcb won by taking wickets
g=a['result'].value_counts()
g.plot.pie(autopct="%.1f%%");

# %%
# insight 7
# team 1 and team 2 with winner and eliminator
dfrcb.groupby(['team1','team2','eliminator'])['winner'].value_counts()
# Out:
# team1                        team2                        eliminator  winner
# Chennai Super Kings          Royal Challengers Bangalore  N           Chennai Super Kings             9
#                                                                       Royal Challengers Bangalore     2
# Deccan Chargers              Royal Challengers Bangalore  N           Deccan Chargers                 3
#                                                                       Royal Challengers Bangalore     1
# Delhi Capitals               Royal Challengers Bangalore  N           Delhi Capitals                  2
# Delhi Daredevils             Royal Challengers Bangalore  N           Royal Challengers Bangalore     8
#                                                                       Delhi Daredevils                2
# Gujarat Lions                Royal Challengers Bangalore  N           Royal Challengers Bangalore     2
# ...

# %%
import re

# %%
df[df['umpire1'].str.count('^[pP].*')>0]
# Out:
#           id           city       date player_of_match  \
# 193   501216          Delhi 2011-04-19         S Sohal
# 206   501230          Delhi 2011-04-28       MK Tiwary
# 234   501258         Indore 2011-05-15        BJ Hodge
# 469   829727  Visakhapatnam 2015-04-16       AM Rahane
# 471   829731  Visakhapatnam 2015-04-18       JP Duminy
# 770  1216506      Abu Dhabi 2020-11-01      RD Gaikwad
# 776  1216512      Abu Dhabi 2020-10-18     LH Ferguson
# 813  1237178      Abu Dhabi 2020-11-06   KS Williamson
# 814  1237180      Abu Dhabi 2020-11-08      MP Stoinis
#
#                                                  venue  neutral_venue  \
# 193                                   Feroz Shah Kotla              0
# 206                                   Feroz Shah Kotla              0
# 234                             Holkar Cricket Stadium              0
# 469  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...              0
# ...

# %%
dfrcb[dfrcb['city'].str.count('^[I].*')>0]# that contains I in City
# Out:
#           id    city       date player_of_match                   venue  \
# 584  1082598  Indore 2017-04-10        AR Patel  Holkar Cricket Stadium
# 683  1136608  Indore 2018-05-14        UT Yadav  Holkar Cricket Stadium
#
#      neutral_venue            team1                        team2  \
# 584              0  Kings XI Punjab  Royal Challengers Bangalore
# 683              0  Kings XI Punjab  Royal Challengers Bangalore
#
#                      toss_winner toss_decision                       winner  \
# 584  Royal Challengers Bangalore           bat              Kings XI Punjab
# 683  Royal Challengers Bangalore         field  Royal Challengers Bangalore
#
#       result result_margin eliminator       umpire1        umpire2  year
# 584  wickets           8.0          N  AK Chaudhary  C Shamshuddin  2017
# 683  wickets          10.0          N  BNJ Oxenford      VK Sharma  2018

# %% [markdown]
# Kings XI Punjab

# %%
k1=df.iloc[np.where(df['team1']=='Kings XI Punjab')]

# %%
k2=df.iloc[np.where(df['team2']=='Kings XI Punjab')]

# %%
dfk=pd.concat([k1,k2],axis=0)

# %%
dfk
# Out:
#           id        city       date player_of_match  \
# 1     335983  Chandigarh 2008-04-19      MEK Hussey
# 9     335991  Chandigarh 2008-04-25   KC Sangakkara
# 13    335995  Chandigarh 2008-04-27       SM Katich
# 21    336003  Chandigarh 2008-05-03       IK Pathan
# 34    336016  Chandigarh 2008-05-12        SE Marsh
# ..       ...         ...        ...             ...
# 784  1216520     Sharjah 2020-10-26        CH Gayle
# 787  1216523   Abu Dhabi 2020-10-10      KD Karthik
# 795  1216531     Sharjah 2020-10-15        KL Rahul
# 806  1216542       Dubai 2020-10-08     JM Bairstow
# 810  1216546       Dubai 2020-10-20        S Dhawan
#
#                                           venue  neutral_venue  \
# 1    Punjab Cricket Association Stadium, Mohali              0
# 9    Punjab Cricket Association Stadium, Mohali              0
# 13   Punjab Cricket Association Stadium, Mohali              0
# 21   Punjab Cricket Association Stadium, Mohali              0
# ...

# %%
dfk['winner'].value_counts()
# Out:
# Kings XI Punjab                88
# Kolkata Knight Riders          18
# Chennai Super Kings            14
# Mumbai Indians                 14
# Royal Challengers Bangalore    12
# Rajasthan Royals               12
# Sunrisers Hyderabad            11
# Delhi Daredevils                9
# Deccan Chargers                 3
# Pune Warriors                   3
# Delhi Capitals                  2
# Gujarat Lions                   2
# Rising Pune Supergiant          1
# Rising Pune Supergiants         1
# Name: winner, dtype: int64

# %%
# insight 2
# venues of matches played by krk with their dates
dfk.groupby(['city','date'])['venue'].value_counts()
# Out:
# city           date        venue
# Abu Dhabi      2014-04-18  Sheikh Zayed Stadium                                   1
#                2014-04-26  Sheikh Zayed Stadium                                   1
#                2020-10-01  Sheikh Zayed Stadium                                   1
#                2020-10-10  Sheikh Zayed Stadium                                   1
#                2020-10-30  Sheikh Zayed Stadium                                   1
#                                                                                  ..
# Sharjah        2020-09-27  Sharjah Cricket Stadium                                1
#                2020-10-15  Sharjah Cricket Stadium                                1
#                2020-10-26  Sharjah Cricket Stadium                                1
# Visakhapatnam  2016-05-13  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium    1
#                2016-05-21  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium    1
# ...

# %%
# insight 3
# Teams and their no. of match won
dfk.groupby(['team1','team2'])['winner'].value_counts()
# Out:
# team1                        team2                        winner
# Chennai Super Kings          Kings XI Punjab              Chennai Super Kings            8
#                                                           Kings XI Punjab                4
# Deccan Chargers              Kings XI Punjab              Kings XI Punjab                5
#                                                           Deccan Chargers                1
# Delhi Capitals               Kings XI Punjab              Delhi Capitals                 2
#                                                           Kings XI Punjab                1
# Delhi Daredevils             Kings XI Punjab              Delhi Daredevils               6
#                                                           Kings XI Punjab                6
# Gujarat Lions                Kings XI Punjab              Kings XI Punjab                2
# Kings XI Punjab              Chennai Super Kings          Chennai Super Kings            6
# ...

# %%
# insight 4
dfk['venue'].value_counts()
# Out:
# Punjab Cricket Association Stadium, Mohali              35
# Punjab Cricket Association IS Bindra Stadium, Mohali    21
# Wankhede Stadium                                        11
# Eden Gardens                                            11
# Feroz Shah Kotla                                        11
# Rajiv Gandhi International Stadium, Uppal               10
# M Chinnaswamy Stadium                                   10
# Himachal Pradesh Cricket Association Stadium             9
# Holkar Cricket Stadium                                   8
# Dubai International Cricket Stadium                      8
# Sheikh Zayed Stadium                                     6
# MA Chidambaram Stadium, Chepauk                          6
# Kingsmead                                                6
# Sawai Mansingh Stadium                                   6
# Sharjah Cricket Stadium                                  5
# Maharashtra Cricket Association Stadium                  5
# ...

# %%
b=dfk.iloc[np.where(dfk['winner']=='Kings XI Punjab')]

# %%
b.groupby(['toss_winner'])['toss_decision'].value_counts()
# Out:
# toss_winner                  toss_decision
# Chennai Super Kings          field             4
#                              bat               1
# Deccan Chargers              field             2
#                              bat               1
# Delhi Capitals               bat               1
#                              field             1
# Delhi Daredevils             field             4
#                              bat               3
# Gujarat Lions                field             2
# Kings XI Punjab              field            30
#                              bat               6
# Kolkata Knight Riders        field             4
#                              bat               2
# Mumbai Indians               field             6
#                              bat               4
# Pune Warriors                bat               1
# Rajasthan Royals             field             5
# Rising Pune Supergiants      bat               1
# ...

# %%
# insight 5
# how Punjab won from other team accordin to result
b.groupby(['team1','team2','result','result_margin'])['result'].value_counts()
# Out:
# team1                        team2            result   result_margin  result
# Chennai Super Kings          Kings XI Punjab  runs     7.0            runs       1
#                                                        24.0           runs       1
#                                               tie      Not Available  tie        1
#                                               wickets  6.0            wickets    1
# Deccan Chargers              Kings XI Punjab  runs     1.0            runs       1
#                                                                                 ..
# Royal Challengers Bangalore  Kings XI Punjab  wickets  4.0            wickets    1
#                                                        6.0            wickets    1
#                                                        7.0            wickets    2
#                                                        8.0            wickets    1
# ...

# %%
xc=b['result'].value_counts()
xc.plot.pie(autopct="%.1f%%");

# %%
# insight 7
# team 1 and team 2 with winner and eliminator
dfk.groupby(['team1','team2','eliminator'])['winner'].value_counts()
# Out:
# team1                        team2                        eliminator  winner
# Chennai Super Kings          Kings XI Punjab              N           Chennai Super Kings            8
#                                                                       Kings XI Punjab                3
#                                                           Y           Kings XI Punjab                1
# Deccan Chargers              Kings XI Punjab              N           Kings XI Punjab                5
#                                                                       Deccan Chargers                1
# Delhi Capitals               Kings XI Punjab              N           Delhi Capitals                 1
#                                                                       Kings XI Punjab                1
#                                                           Y           Delhi Capitals                 1
# ...

# %%
dfk.groupby('winner')['eliminator'].value_counts()
# Out:
# winner                       eliminator
# Chennai Super Kings          N             14
# Deccan Chargers              N              3
# Delhi Capitals               N              1
#                              Y              1
# Delhi Daredevils             N              9
# Gujarat Lions                N              2
# Kings XI Punjab              N             85
#                              Y              3
# Kolkata Knight Riders        N             18
# Mumbai Indians               N             14
# Pune Warriors                N              3
# Rajasthan Royals             N             12
# Rising Pune Supergiant       N              1
# Rising Pune Supergiants      N              1
# Royal Challengers Bangalore  N             12
# Sunrisers Hyderabad          N             11
# Name: eliminator, dtype: int64

# %%
dfd1=df.iloc[np.where(df['team1']=='Delhi Daredevils')]

# %%
dfd2=df.iloc[np.where(df['team2']=='Delhi Daredevils')]

# %%
dfd=pd.concat([dfd1,dfd2],axis=0)

# %%
dfd # DD has played 159 matches only.
# Out:
#           id       city       date   player_of_match  \
# 2     335984      Delhi 2008-04-19       MF Maharoof
# 16    335998      Delhi 2008-04-30        GD McGrath
# 27    336009      Delhi 2008-05-08          MS Dhoni
# 38    336020      Delhi 2008-05-15          A Mishra
# 40    336022      Delhi 2008-05-17  DPMD Jayawardene
# ..       ...        ...        ...               ...
# 644  1136569     Mumbai 2018-04-14            JJ Roy
# 648  1136573    Kolkata 2018-04-16            N Rana
# 654  1136579  Bengaluru 2018-04-21    AB de Villiers
# 665  1136590       Pune 2018-04-30         SR Watson
# 671  1136596  Hyderabad 2018-05-05       Rashid Khan
#
#                                          venue  neutral_venue  \
# 2                             Feroz Shah Kotla              0
# 16                            Feroz Shah Kotla              0
# 27                            Feroz Shah Kotla              0
# 38                            Feroz Shah Kotla              0
# ...

# %%
dfd['winner'].value_counts()
# Out:
# Delhi Daredevils               67
# Royal Challengers Bangalore    14
# Kings XI Punjab                13
# Kolkata Knight Riders          13
# Chennai Super Kings            12
# Rajasthan Royals               11
# Mumbai Indians                 11
# Sunrisers Hyderabad             8
# Deccan Chargers                 4
# Rising Pune Supergiants         2
# Pune Warriors                   2
# Gujarat Lions                   1
# Kochi Tuskers Kerala            1
# Name: winner, dtype: int64

# %%
# insight 2
# venues of matches played by punjab with their dates
dfd.groupby(['city','date'])['venue'].value_counts()
# Out:
# city           date        venue
# Abu Dhabi      2014-04-21  Sheikh Zayed Stadium                                   1
# Ahmedabad      2010-03-15  Sardar Patel Stadium, Motera                           1
#                2014-05-15  Sardar Patel Stadium, Motera                           1
# Bangalore      2008-05-19  M Chinnaswamy Stadium                                  1
#                2010-03-25  M Chinnaswamy Stadium                                  1
#                                                                                  ..
# Raipur         2016-05-22  Shaheed Veer Narayan Singh International Stadium       1
# Rajkot         2016-05-03  Saurashtra Cricket Association Stadium                 1
# Visakhapatnam  2015-04-18  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium    1
#                2016-05-15  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium    1
#                2016-05-17  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium    1
# ...

# %%
# insight 3
# Teams and their no. of match won
dfd.groupby(['team1','team2'])['winner'].value_counts()
# Out:
# team1                        team2                        winner
# Chennai Super Kings          Delhi Daredevils             Chennai Super Kings            7
#                                                           Delhi Daredevils               3
# Deccan Chargers              Delhi Daredevils             Delhi Daredevils               5
#                                                           Deccan Chargers                1
# Delhi Daredevils             Chennai Super Kings          Chennai Super Kings            5
#                                                           Delhi Daredevils               3
#                              Deccan Chargers              Deccan Chargers                3
#                                                           Delhi Daredevils               2
#                              Gujarat Lions                Delhi Daredevils               1
#                                                           Gujarat Lions                  1
# ...

# %%
# insight 4
dfd['venue'].value_counts()
# Out:
# Feroz Shah Kotla                                        62
# Eden Gardens                                             8
# Wankhede Stadium                                         8
# MA Chidambaram Stadium, Chepauk                          7
# Rajiv Gandhi International Stadium, Uppal                7
# Shaheed Veer Narayan Singh International Stadium         6
# M Chinnaswamy Stadium                                    6
# Sawai Mansingh Stadium                                   5
# SuperSport Park                                          4
# Himachal Pradesh Cricket Association Stadium             3
# Kingsmead                                                3
# Punjab Cricket Association Stadium, Mohali               3
# Punjab Cricket Association IS Bindra Stadium, Mohali     3
# Subrata Roy Sahara Stadium                               3
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium      3
# Maharashtra Cricket Association Stadium                  3
# ...

# %%
c=dfd.iloc[np.where(dfd['winner']=='Delhi Daredevils')]

# %%
# insight 5
# how Punjab won from other team accordin to result
c.groupby(['team1','team2','result','result_margin'])['result'].value_counts()
# Out:
# team1                        team2                        result   result_margin  result
# Chennai Super Kings          Delhi Daredevils             runs     9.0            runs       1
#                                                           wickets  6.0            wickets    1
#                                                                    8.0            wickets    1
# Deccan Chargers              Delhi Daredevils             runs     12.0           runs       1
#                                                           wickets  4.0            wickets    1
#                                                                    6.0            wickets    1
#                                                                    9.0            wickets    2
# Delhi Daredevils             Chennai Super Kings          runs     34.0           runs       1
#                                                           wickets  6.0            wickets    1
# ...

# %%
xz=c['result'].value_counts()
xz.plot.pie(autopct="%.1f%%");

# %%
# insight 7
# team 1 and team 2 with winner and eliminator
dfd.groupby(['team1','team2','eliminator'])['winner'].value_counts()
# Out:
# team1                        team2                        eliminator  winner
# Chennai Super Kings          Delhi Daredevils             N           Chennai Super Kings            7
#                                                                       Delhi Daredevils               3
# Deccan Chargers              Delhi Daredevils             N           Delhi Daredevils               5
#                                                                       Deccan Chargers                1
# Delhi Daredevils             Chennai Super Kings          N           Chennai Super Kings            5
#                                                                       Delhi Daredevils               3
#                              Deccan Chargers              N           Deccan Chargers                3
#                                                                       Delhi Daredevils               2
# ...

# %%
# insight 8
dfd.groupby(['winner'])['eliminator'].value_counts()
# Out:
# winner                       eliminator
# Chennai Super Kings          N             12
# Deccan Chargers              N              4
# Delhi Daredevils             N             67
# Gujarat Lions                N              1
# Kings XI Punjab              N             13
# Kochi Tuskers Kerala         N              1
# Kolkata Knight Riders        N             13
# Mumbai Indians               N             11
# Pune Warriors                N              2
# Rajasthan Royals             N             11
# Rising Pune Supergiants      N              2
# Royal Challengers Bangalore  N             13
#                              Y              1
# Sunrisers Hyderabad          N              8
# Name: eliminator, dtype: int64

# %%
df['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiant', 'Delhi Capitals'],
#       dtype=object)

# %%
df['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiant', 'Delhi Capitals'],
#       dtype=object)

# %%
dfkrk1=df.iloc[np.where(df['team1']==('Kolkata Knight Riders'))]

# %%
dfkrk2=df.iloc[np.where(df['team2']==('Kolkata Knight Riders'))]

# %%
dfkrk=pd.concat([dfkrk1,dfkrk2],axis=0)

# %%
dfkrk # Kolkata has played 192 matches
# Out:
#           id       city       date player_of_match                    venue  \
# 4     335986    Kolkata 2008-04-20       DJ Hussey             Eden Gardens
# 15    335997    Kolkata 2008-04-29   ST Jayasuriya             Eden Gardens
# 28    336010    Kolkata 2008-05-08      SC Ganguly             Eden Gardens
# 35    336017    Kolkata 2008-05-13   Shoaib Akhtar             Eden Gardens
# 43    336025    Kolkata 2008-05-18         M Ntini             Eden Gardens
# ..       ...        ...        ...             ...                      ...
# 751  1178431     Mumbai 2019-05-05       HH Pandya         Wankhede Stadium
# 772  1216508  Abu Dhabi 2020-09-23       RG Sharma     Sheikh Zayed Stadium
# 779  1216515    Sharjah 2020-10-03         SS Iyer  Sharjah Cricket Stadium
# 804  1216540    Sharjah 2020-10-12  AB de Villiers  Sharjah Cricket Stadium
# 809  1216545  Abu Dhabi 2020-09-26    Shubman Gill     Sheikh Zayed Stadium
#
# ...

# %%
dfkrk['winner'].value_counts()
# Out:
# Kolkata Knight Riders          99
# Mumbai Indians                 21
# Chennai Super Kings            14
# Royal Challengers Bangalore    12
# Rajasthan Royals               10
# Kings XI Punjab                 9
# Delhi Daredevils                8
# Sunrisers Hyderabad             7
# Delhi Capitals                  3
# Gujarat Lions                   3
# Kochi Tuskers Kerala            2
# Deccan Chargers                 2
# Rising Pune Supergiant          1
# Pune Warriors                   1
# Name: winner, dtype: int64

# %%
# insight 2
# venues of matches played by Kolkata with their dates
dfkrk.groupby(['city','date'])['venue'].value_counts()
# Out:
# city           date        venue
# Abu Dhabi      2014-04-16  Sheikh Zayed Stadium                                   1
#                2014-04-26  Sheikh Zayed Stadium                                   1
#                2014-04-29  Sheikh Zayed Stadium                                   1
#                2020-09-23  Sheikh Zayed Stadium                                   1
#                2020-09-26  Sheikh Zayed Stadium                                   1
#                                                                                  ..
# Ranchi         2014-05-02  JSCA International Stadium Complex                     1
# Sharjah        2020-10-03  Sharjah Cricket Stadium                                1
#                2020-10-12  Sharjah Cricket Stadium                                1
#                2020-10-26  Sharjah Cricket Stadium                                1
# Visakhapatnam  2015-04-22  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium    1
# ...

# %%
# insight 3
# Teams and their no. of match won
dfkrk.groupby(['team1','team2'])['winner'].value_counts()
# Out:
# team1                        team2                        winner
# Chennai Super Kings          Kolkata Knight Riders        Chennai Super Kings             8
#                                                           Kolkata Knight Riders           2
# Deccan Chargers              Kolkata Knight Riders        Kolkata Knight Riders           4
#                                                           Deccan Chargers                 2
# Delhi Capitals               Kolkata Knight Riders        Delhi Capitals                  2
# Delhi Daredevils             Kolkata Knight Riders        Delhi Daredevils                6
#                                                           Kolkata Knight Riders           6
# Gujarat Lions                Kolkata Knight Riders        Gujarat Lions                   1
#                                                           Kolkata Knight Riders           1
# ...

# %%
# insight 4
dfkrk['venue'].value_counts()
# Out:
# Eden Gardens                                            74
# Sheikh Zayed Stadium                                    11
# M Chinnaswamy Stadium                                   11
# Feroz Shah Kotla                                        10
# MA Chidambaram Stadium, Chepauk                          9
# Wankhede Stadium                                         9
# Rajiv Gandhi International Stadium, Uppal                8
# Sawai Mansingh Stadium                                   6
# Punjab Cricket Association Stadium, Mohali               4
# Sharjah Cricket Stadium                                  4
# Dubai International Cricket Stadium                      4
# Kingsmead                                                4
# Maharashtra Cricket Association Stadium                  3
# Punjab Cricket Association IS Bindra Stadium, Mohali     3
# Barabati Stadium                                         3
# JSCA International Stadium Complex                       3
# ...

# %%
d=dfkrk.iloc[np.where(dfkrk['winner']=='Kolkata Knight Riders')]

# %%
xx=d['result'].value_counts()
xx.plot.pie(autopct="%.1f%%");

# %%
# insight 5
# how Kolkata won from other team accordin to result
d.groupby(['team1','team2','result','result_margin'])['result'].value_counts()
# Out:
# team1                        team2                  result   result_margin  result
# Chennai Super Kings          Kolkata Knight Riders  wickets  5.0            wickets    1
#                                                              7.0            wickets    1
# Deccan Chargers              Kolkata Knight Riders  runs     11.0           runs       1
#                                                              20.0           runs       1
#                                                              23.0           runs       1
#                                                                                       ..
# Royal Challengers Bangalore  Kolkata Knight Riders  wickets  5.0            wickets    2
#                                                              6.0            wickets    2
# Sunrisers Hyderabad          Kolkata Knight Riders  wickets  5.0            wickets    1
#                                                              7.0            wickets    3
# ...

# %%
# insight 7
# team 1 and team 2 with winner and eliminator
dfkrk.groupby(['team1','team2','eliminator'])['winner'].value_counts()
# Out:
# team1                        team2                        eliminator  winner
# Chennai Super Kings          Kolkata Knight Riders        N           Chennai Super Kings             8
#                                                                       Kolkata Knight Riders           2
# Deccan Chargers              Kolkata Knight Riders        N           Kolkata Knight Riders           4
#                                                                       Deccan Chargers                 2
# Delhi Capitals               Kolkata Knight Riders        N           Delhi Capitals                  1
#                                                           Y           Delhi Capitals                  1
# Delhi Daredevils             Kolkata Knight Riders        N           Delhi Daredevils                6
#                                                                       Kolkata Knight Riders           6
# ...

# %%
# insight 8
dfkrk.groupby(['winner'])['eliminator'].value_counts()
# Out:
# winner                       eliminator
# Chennai Super Kings          N             14
# Deccan Chargers              N              2
# Delhi Capitals               N              2
#                              Y              1
# Delhi Daredevils             N              8
# Gujarat Lions                N              3
# Kings XI Punjab              N              9
# Kochi Tuskers Kerala         N              2
# Kolkata Knight Riders        N             98
#                              Y              1
# Mumbai Indians               N             21
# Pune Warriors                N              1
# Rajasthan Royals             N              8
#                              Y              2
# Rising Pune Supergiant       N              1
# Royal Challengers Bangalore  N             12
# Sunrisers Hyderabad          N              7
# Name: eliminator, dtype: int64

# %%
df['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiant', 'Delhi Capitals'],
#       dtype=object)

# %%
dfm1=df.iloc[np.where(df['team1']=='Mumbai Indians')]

# %%
dfm2=df.iloc[np.where(df['team2']=='Mumbai Indians')]

# %%
dfm=pd.concat([dfm1,dfm2],axis=0)

# %%
dfm # mumbai has played 203 matches
# Out:
#           id       city       date player_of_match  \
# 3     335985     Mumbai 2008-04-20      MV Boucher
# 12    335994     Mumbai 2008-04-27    AC Gilchrist
# 22    336004     Mumbai 2008-05-04      SM Pollock
# 26    336008     Mumbai 2008-05-07         A Nehra
# 36    336018     Mumbai 2008-05-14   ST Jayasuriya
# ..       ...        ...        ...             ...
# 790  1216526  Abu Dhabi 2020-10-16       Q de Kock
# 793  1216529  Abu Dhabi 2020-10-11       Q de Kock
# 799  1216535      Dubai 2020-10-31    Ishan Kishan
# 811  1216547      Dubai 2020-09-28  AB de Villiers
# 815  1237181      Dubai 2020-11-10        TA Boult
#
#                                    venue  neutral_venue  \
# 3                       Wankhede Stadium              0
# 12            Dr DY Patil Sports Academy              0
# 22            Dr DY Patil Sports Academy              0
# 26            Dr DY Patil Sports Academy              0
# 36                      Wankhede Stadium              0
# ...

# %%
dfm['winner'].value_counts()
# Out:
# Mumbai Indians                 120
# Chennai Super Kings             12
# Kings XI Punjab                 12
# Delhi Daredevils                11
# Rajasthan Royals                11
# Royal Challengers Bangalore     10
# Sunrisers Hyderabad              8
# Kolkata Knight Riders            6
# Deccan Chargers                  4
# Rising Pune Supergiant           3
# Gujarat Lions                    2
# Delhi Capitals                   1
# Kochi Tuskers Kerala             1
# Rising Pune Supergiants          1
# Pune Warriors                    1
# Name: winner, dtype: int64

# %%
# insight 2
# venues of matches played by Mumbai with their dates
dfm.groupby(['city','date'])['venue'].value_counts()
# Out:
# city           date        venue
# Abu Dhabi      2014-04-16  Sheikh Zayed Stadium                                   1
#                2020-09-19  Sheikh Zayed Stadium                                   1
#                2020-09-23  Sheikh Zayed Stadium                                   1
#                2020-10-01  Sheikh Zayed Stadium                                   1
#                2020-10-06  Sheikh Zayed Stadium                                   1
#                                                                                  ..
# Sharjah        2020-11-03  Sharjah Cricket Stadium                                1
# Visakhapatnam  2012-04-09  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium    1
#                2016-05-08  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium    1
#                2016-05-13  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium    1
#                2016-05-15  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium    1
# ...

# %%
# insight 3
# Teams and their no. of match won
dfm.groupby(['team1','team2'])['winner'].value_counts()
# Out:
# team1                        team2                        winner
# Chennai Super Kings          Mumbai Indians               Mumbai Indians                  9
#                                                           Chennai Super Kings             8
# Deccan Chargers              Mumbai Indians               Mumbai Indians                  4
#                                                           Deccan Chargers                 2
# Delhi Capitals               Mumbai Indians               Mumbai Indians                  4
# Delhi Daredevils             Mumbai Indians               Delhi Daredevils                9
#                                                           Mumbai Indians                  3
# Gujarat Lions                Mumbai Indians               Gujarat Lions                   1
#                                                           Mumbai Indians                  1
# ...

# %%
dfm['venue'].value_counts()
# Out:
# Wankhede Stadium                                        67
# Eden Gardens                                            13
# Rajiv Gandhi International Stadium, Uppal               11
# Feroz Shah Kotla                                        11
# M Chinnaswamy Stadium                                   10
# Sheikh Zayed Stadium                                     9
# Brabourne Stadium                                        8
# MA Chidambaram Stadium, Chepauk                          8
# Dubai International Cricket Stadium                      8
# Dr DY Patil Sports Academy                               7
# Sawai Mansingh Stadium                                   7
# Punjab Cricket Association Stadium, Mohali               6
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium      4
# Sharjah Cricket Stadium                                  4
# SuperSport Park                                          3
# St George's Park                                         3
# ...

# %%
e=dfm.iloc[np.where(dfm['winner']=='Mumbai Indians')]

# %%
# insight 5
# how Mumbai won from other team accordin to result
e.groupby(['team1','team2','result','result_margin'])['result'].value_counts()
# Out:
# team1                        team2           result   result_margin  result
# Chennai Super Kings          Mumbai Indians  runs     9.0            runs       1
#                                                       19.0           runs       1
#                                                       23.0           runs       1
#                                                       25.0           runs       1
#                                                       46.0           runs       1
#                                                                                ..
# Royal Challengers Bangalore  Mumbai Indians  wickets  6.0            wickets    1
#                                                       9.0            wickets    2
# Sunrisers Hyderabad          Mumbai Indians  runs     40.0           runs       1
#                                              wickets  7.0            wickets    1
# ...

# %%
xs=e['result'].value_counts()
xs.plot.pie(autopct="%.1f%%");

# %%
# insight 7
# team 1 and team 2 with winner and eliminator
dfm.groupby(['team1','team2','eliminator'])['winner'].value_counts()
# Out:
# team1                        team2                        eliminator  winner
# Chennai Super Kings          Mumbai Indians               N           Mumbai Indians                  9
#                                                                       Chennai Super Kings             8
# Deccan Chargers              Mumbai Indians               N           Mumbai Indians                  4
#                                                                       Deccan Chargers                 2
# Delhi Capitals               Mumbai Indians               N           Mumbai Indians                  4
# Delhi Daredevils             Mumbai Indians               N           Delhi Daredevils                9
#                                                                       Mumbai Indians                  3
# Gujarat Lions                Mumbai Indians               N           Gujarat Lions                   1
# ...

# %%
# insight 8
dfm.groupby(['winner'])['eliminator'].value_counts()
# Out:
# winner                       eliminator
# Chennai Super Kings          N              12
# Deccan Chargers              N               4
# Delhi Capitals               N               1
# Delhi Daredevils             N              11
# Gujarat Lions                N               2
# Kings XI Punjab              N              11
#                              Y               1
# Kochi Tuskers Kerala         N               1
# Kolkata Knight Riders        N               6
# Mumbai Indians               N             118
#                              Y               2
# Pune Warriors                N               1
# Rajasthan Royals             N              11
# Rising Pune Supergiant       N               3
# Rising Pune Supergiants      N               1
# Royal Challengers Bangalore  N               9
#                              Y               1
# Sunrisers Hyderabad          N               8
# Name: eliminator, dtype: int64

# %%
df['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiant', 'Delhi Capitals'],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'umpire1', 'umpire2', 'year'],
#       dtype='object')

# %%
df.groupby(['team1','team2'])['id'].value_counts()
# Out:
# team1                team2                        id
# Chennai Super Kings  Deccan Chargers              336007     1
#                                                   392196     1
#                                                   392209     1
#                                                   419110     1
#                                                   419163     1
#                                                             ..
# Sunrisers Hyderabad  Royal Challengers Bangalore  829807     1
#                                                   980953     1
#                                                   1082591    1
#                                                   1136599    1
#                                                   1175366    1
# Name: id, Length: 812, dtype: int64

# %%
qq=df.groupby(['year'])['date'].agg(['min','max'])

# %%
qq
# Out:
#             min        max
# year
# 2008 2008-04-18 2008-06-01
# 2009 2009-04-18 2009-05-24
# 2010 2010-03-12 2010-04-25
# 2011 2011-04-08 2011-05-28
# 2012 2012-04-04 2012-05-27
# 2013 2013-04-03 2013-05-26
# 2014 2014-04-16 2014-06-01
# 2015 2015-04-08 2015-05-24
# 2016 2016-04-09 2016-05-29
# 2017 2017-04-05 2017-05-21
# 2018 2018-04-07 2018-05-27
# 2019 2019-03-23 2019-05-12
# 2020 2020-09-19 2020-11-10

# %%
df.iloc[np.where((df['year']==2008)&(df['date']=='2008-06-01'))]
# Out:
#         id    city       date player_of_match                       venue  \
# 57  336040  Mumbai 2008-06-01       YK Pathan  Dr DY Patil Sports Academy
#
#     neutral_venue                team1             team2       toss_winner  \
# 57              0  Chennai Super Kings  Rajasthan Royals  Rajasthan Royals
#
#    toss_decision            winner   result result_margin eliminator  \
# 57         field  Rajasthan Royals  wickets           3.0          N
#
#       umpire1      umpire2  year
# 57  BF Bowden  RE Koertzen  2008

# %%
df.iloc[np.where((df['year']==2009)&(df['date']=='2009-05-24'))]
# Out:
#          id          city       date player_of_match                  venue  \
# 114  392239  Johannesburg 2009-05-24        A Kumble  New Wanderers Stadium
#
#      neutral_venue                        team1            team2  \
# 114              1  Royal Challengers Bangalore  Deccan Chargers
#
#                      toss_winner toss_decision           winner result  \
# 114  Royal Challengers Bangalore         field  Deccan Chargers   runs
#
#     result_margin eliminator      umpire1     umpire2  year
# 114           6.0          N  RE Koertzen  SJA Taufel  2009

# %%
df.iloc[np.where((df['year']==2010)&(df['date']=='2010-04-25'))] #2010
# Out:
#          id    city       date player_of_match                       venue  \
# 174  419165  Mumbai 2010-04-25        SK Raina  Dr DY Patil Sports Academy
#
#      neutral_venue                team1           team2          toss_winner  \
# 174              0  Chennai Super Kings  Mumbai Indians  Chennai Super Kings
#
#     toss_decision               winner result result_margin eliminator  \
# 174           bat  Chennai Super Kings   runs          22.0          N
#
#          umpire1     umpire2  year
# 174  RE Koertzen  SJA Taufel  2010

# %%
df.iloc[np.where((df['year']==2011)&(df['date']=='2011-05-28'))] #2011
# Out:
#          id     city       date player_of_match  \
# 247  501271  Chennai 2011-05-28         M Vijay
#
#                                venue  neutral_venue                team1  \
# 247  MA Chidambaram Stadium, Chepauk              0  Chennai Super Kings
#
#                            team2          toss_winner toss_decision  \
# 247  Royal Challengers Bangalore  Chennai Super Kings           bat
#
#                   winner result result_margin eliminator    umpire1  \
# 247  Chennai Super Kings   runs          58.0          N  Asad Rauf
#
#         umpire2  year
# 247  SJA Taufel  2011

# %%
df.iloc[np.where((df['year']==2012)&(df['date']=='2012-05-27'))] #2012
# Out:
#          id     city       date player_of_match  \
# 321  548381  Chennai 2012-05-27        MS Bisla
#
#                                venue  neutral_venue                  team1  \
# 321  MA Chidambaram Stadium, Chepauk              0  Kolkata Knight Riders
#
#                    team2          toss_winner toss_decision  \
# 321  Chennai Super Kings  Chennai Super Kings           bat
#
#                     winner   result result_margin eliminator    umpire1  \
# 321  Kolkata Knight Riders  wickets           5.0          N  BF Bowden
#
#         umpire2  year
# 321  SJA Taufel  2012

# %%
df.iloc[np.where((df['year']==2013)&(df['date']=='2013-06-26'))] #2013
# Out:
# Empty DataFrame
# Columns: [id, city, date, player_of_match, venue, neutral_venue, team1, team2, toss_winner, toss_decision, winner, result, result_margin, eliminator, umpire1, umpire2, year]
# Index: []

# %%
df.iloc[np.where((df['year']==2014)&(df['date']=='2014-06-01'))] #2014
# Out:
#          id       city       date player_of_match                  venue  \
# 457  734049  Bangalore 2014-06-01       MK Pandey  M Chinnaswamy Stadium
#
#      neutral_venue                  team1            team2  \
# 457              0  Kolkata Knight Riders  Kings XI Punjab
#
#                toss_winner toss_decision                 winner   result  \
# 457  Kolkata Knight Riders         field  Kolkata Knight Riders  wickets
#
#     result_margin eliminator          umpire1       umpire2  year
# 457           3.0          N  HDPK Dharmasena  BNJ Oxenford  2014

# %%
df.iloc[np.where((df['year']==2015)&(df['date']=='2015-05-24'))] #2015
# Out:
#          id     city       date player_of_match         venue  neutral_venue  \
# 516  829823  Kolkata 2015-05-24       RG Sharma  Eden Gardens              0
#
#               team1                team2          toss_winner toss_decision  \
# 516  Mumbai Indians  Chennai Super Kings  Chennai Super Kings         field
#
#              winner result result_margin eliminator          umpire1  \
# 516  Mumbai Indians   runs          41.0          N  HDPK Dharmasena
#
#             umpire2  year
# 516  RK Illingworth  2015

# %%
df.iloc[np.where((df['year']==2016)&(df['date']=='2016-05-29'))] #2016
# Out:
#          id       city       date player_of_match                  venue  \
# 576  981019  Bangalore 2016-05-29     BCJ Cutting  M Chinnaswamy Stadium
#
#      neutral_venue                        team1                team2  \
# 576              0  Royal Challengers Bangalore  Sunrisers Hyderabad
#
#              toss_winner toss_decision               winner result  \
# 576  Sunrisers Hyderabad           bat  Sunrisers Hyderabad   runs
#
#     result_margin eliminator          umpire1       umpire2  year
# 576           8.0          N  HDPK Dharmasena  BNJ Oxenford  2016

# %%
df.iloc[np.where((df['year']==2017)&(df['date']=='2017-05-21'))] #2017
# Out:
#           id       city       date player_of_match  \
# 635  1082650  Hyderabad 2017-05-21       KH Pandya
#
#                                          venue  neutral_venue           team1  \
# 635  Rajiv Gandhi International Stadium, Uppal              0  Mumbai Indians
#
#                       team2     toss_winner toss_decision          winner  \
# 635  Rising Pune Supergiant  Mumbai Indians           bat  Mumbai Indians
#
#     result result_margin eliminator   umpire1 umpire2  year
# 635   runs           1.0          N  NJ Llong  S Ravi  2017

# %%
df.iloc[np.where((df['year']==2018)&(df['date']=='2018-05-27'))] #2018
# Out:
#           id    city       date player_of_match             venue  \
# 695  1136620  Mumbai 2018-05-27       SR Watson  Wankhede Stadium
#
#      neutral_venue                team1                team2  \
# 695              0  Chennai Super Kings  Sunrisers Hyderabad
#
#              toss_winner toss_decision               winner   result  \
# 695  Chennai Super Kings         field  Chennai Super Kings  wickets
#
#     result_margin eliminator    umpire1 umpire2  year
# 695           8.0          N  M Erasmus  S Ravi  2018

# %%
df.iloc[np.where((df['year']==2019)&(df['date']=='2019-05-12'))] #2019
# Out:
#           id       city       date player_of_match  \
# 755  1181768  Hyderabad 2019-05-12       JJ Bumrah
#
#                                          venue  neutral_venue           team1  \
# 755  Rajiv Gandhi International Stadium, Uppal              0  Mumbai Indians
#
#                    team2     toss_winner toss_decision          winner result  \
# 755  Chennai Super Kings  Mumbai Indians           bat  Mumbai Indians   runs
#
#     result_margin eliminator   umpire1      umpire2  year
# 755           1.0          N  IJ Gould  Nitin Menon  2019

# %%
df.iloc[np.where((df['year']==2020)&(df['date']=='2020-11-10'))] #2020
# Out:
#           id   city       date player_of_match  \
# 815  1237181  Dubai 2020-11-10        TA Boult
#
#                                    venue  neutral_venue           team1  \
# 815  Dubai International Cricket Stadium              0  Delhi Capitals
#
#               team2     toss_winner toss_decision          winner   result  \
# 815  Mumbai Indians  Delhi Capitals           bat  Mumbai Indians  wickets
#
#     result_margin eliminator      umpire1      umpire2  year
# 815           5.0          N  CB Gaffaney  Nitin Menon  2020

# %%
df['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiant', 'Delhi Capitals'],
#       dtype=object)

# %% [markdown]
# - In July 2015, Chennai Super Kings and Rajasthan Royals were suspended from the cash-rich cricket league for two years for betting activities of their key officials Gurunath Meiyappan and Raj Kundra during the 2013 season. Both the officials were banned for life from being involved in any cricket matches conducted by the BCCI.
# - The team played in the IPL for 2 years (the 2016 and 2017 seasons) as one of the replacements for Chennai Super Kings and Rajasthan Royals.

# %% [markdown]
# - The Pune Warriors India were a franchise Twenty20 cricket team that represented the city of Pune in the Indian Premier League (IPL).
# - In May 2013, Pune Warriors India withdrew from the IPL over financial differences with the Board of Control for Cricket in India (BCCI) stemming from the valuation of the league's annual franchise fee.Their last match was on 19 May 2013 against Delhi Daredevils. The franchise was officially terminated by the BCCI five months later, in October 2013.

# %%
df['year'].unique() # Total no. of Seasons.
# Out:
# array([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019, 2020], dtype=int64)

# %% [markdown]
# - The Kochi Tuskers Kerala was a franchise cricket team that played in the Indian Premier League (IPL) representing the city of Kochi, Kerala.The team was one of two new franchises added to the IPL for the 2011 season, alongside Pune Warriors India.
# - The KTK only played for one season, in 2011, and was terminated the following year.

# %% [markdown]
# - The Delhi Capitals are a franchise cricket team based out of Delhi in the Indian Premier League (IPL).The franchise is jointly owned by the GMR Group and the JSW Group. The team's home ground is Arun Jaitley Stadium, located in New Delhi. The Capitals appeared in their first IPL final in 2020

# %%
# Most of the decision by the teams after winning a toss is to Bat first.
cc=df['toss_decision'].value_counts()
cc.plot.pie(autopct="%.1f%%");

# %%
vb=df.iloc[np.where(df['result']=='wickets')]

# %%
zaz=vb.groupby(['result'])['winner'].value_counts()

# %%
# which team has won most of the matches with how much wickets
zaz.plot.pie(autopct="%.1f%%",figsize=(25,20));

# %%
# matches won by the minimum margin
fg=df.iloc[np.where(df['result_margin']==1.0)]

# %%
fg.groupby(['team1','team2'])['winner'].value_counts()
# Out:
# team1                        team2                        winner
# Chennai Super Kings          Delhi Daredevils             Chennai Super Kings            1
# Deccan Chargers              Kings XI Punjab              Kings XI Punjab                1
# Delhi Daredevils             Gujarat Lions                Gujarat Lions                  1
#                              Rajasthan Royals             Delhi Daredevils               1
# Kings XI Punjab              Royal Challengers Bangalore  Royal Challengers Bangalore    1
# Kolkata Knight Riders        Kings XI Punjab              Kolkata Knight Riders          1
# Mumbai Indians               Chennai Super Kings          Chennai Super Kings            1
#                                                           Mumbai Indians                 1
#                              Kings XI Punjab              Kings XI Punjab                1
#                              Rising Pune Supergiant       Mumbai Indians                 1
# ...

# %%
# n.of matches in each season we can say
df['year'].value_counts()
# Out:
# 2013    76
# 2012    74
# 2011    72
# 2010    60
# 2014    60
# 2016    60
# 2018    60
# 2020    60
# 2017    59
# 2019    59
# 2008    58
# 2009    57
# 2015    57
# Name: year, dtype: int64

# %%
# Mumbai Indians is the most successful team.

# %%
sns.countplot(x='year', data=df)
plt.show()

# %%
#sns.countplot(y='winner', data = matches)
#plt.show
data = df.winner.value_counts()
sns.barplot(y = data.index, x = data, orient='h');

# %%
df['id'].max()
# Out:
# 1237181

# %%
len(df['team1'].unique())
# Out:
# 14

# %%
df.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'umpire1', 'umpire2', 'year'],
#       dtype='object')

# %%
df.iloc[np.where(df['result']=='tie')]
# Out:
#           id       city       date player_of_match  \
# 66    392190  Cape Town 2009-04-23       YK Pathan
# 130   419121    Chennai 2010-03-21        J Theron
# 328   598004  Hyderabad 2013-04-07       GH Vihari
# 341   598017  Bangalore 2013-04-16         V Kohli
# 416   729315  Abu Dhabi 2014-04-29     JP Faulkner
# 476   829741  Ahmedabad 2015-04-21        SE Marsh
# 610  1082625     Rajkot 2017-04-29       KH Pandya
# 705  1175365      Delhi 2019-03-30         PP Shaw
# 746  1178426     Mumbai 2019-05-02       JJ Bumrah
# 757  1216493      Dubai 2020-09-20      MP Stoinis
# 776  1216512  Abu Dhabi 2020-10-18     LH Ferguson
# 781  1216517      Dubai 2020-10-18        KL Rahul
# 811  1216547      Dubai 2020-09-28  AB de Villiers
#
#                                          venue  neutral_venue  \
# 66                                    Newlands              1
# 130            MA Chidambaram Stadium, Chepauk              0
# ...

# %%
sns.heatmap( df.corr(),annot=True )
# Out:
# <AxesSubplot:>
