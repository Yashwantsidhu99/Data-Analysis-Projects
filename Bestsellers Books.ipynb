# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import pandas_profiling

# %% [markdown]
# xx is for Non-Fiction Books

# %%
df=pd.read_csv('E:/datasets/bestsellers with categories.csv')

# %%
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %%
df.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %%
df['Name'].value_counts()
# Out:
# Publication Manual of the American Psychological Association, 6th Edition                                       10
# StrengthsFinder 2.0                                                                                              9
# Oh, the Places You'll Go!                                                                                        8
# The Very Hungry Caterpillar                                                                                      7
# The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change                                     7
#                                                                                                                 ..
# Ship of Fools: How a Selfish Ruling Class Is Bringing America to the Brink of Revolution                         1
# Act Like a Lady, Think Like a Man: What Men Really Think About Love, Relationships, Intimacy, and Commitment     1
# ...

# %%
len(df['Name'].unique())
# Out:
# 351

# %%
df['User Rating'].value_counts()
# Out:
# 4.8    127
# 4.7    108
# 4.6    105
# 4.5     60
# 4.9     52
# 4.4     38
# 4.3     25
# 4.0     14
# 4.2      8
# 4.1      6
# 3.9      3
# 3.8      2
# 3.3      1
# 3.6      1
# Name: User Rating, dtype: int64

# %%
df.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %%
sns.distplot(df['User Rating'])
# Out:
# C:\Users\yashw\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='User Rating', ylabel='Density'>

# %%
print(df['User Rating'].mean())
print(df['User Rating'].median())
print(df['User Rating'].mode())
# Out:
# 4.618363636363641
# 4.7
# 0    4.8
# dtype: float64

# %%
import scipy.stats as stats
import pylab

# %%
stats.probplot(df['User Rating'],dist='norm',plot=pylab)
# Out:
# ((array([-3.02105601e+00, -2.74159734e+00, -2.58463985e+00, -2.47343730e+00,
#          -2.38636226e+00, -2.31432444e+00, -2.25260787e+00, -2.19843901e+00,
#          -2.15004332e+00, -2.10621431e+00, -2.06609307e+00, -2.02904562e+00,
#          -1.99459017e+00, -1.96235173e+00, -1.93203245e+00, -1.90339171e+00,
#          -1.87623218e+00, -1.85039002e+00, -1.82572757e+00, -1.80212806e+00,
#          -1.77949153e+00, -1.75773174e+00, -1.73677374e+00, -1.71655195e+00,
#          -1.69700867e+00, -1.67809286e+00, -1.65975910e+00, -1.64196684e+00,
#          -1.62467968e+00, -1.60786485e+00, -1.59149272e+00, -1.57553639e+00,
#          -1.55997141e+00, -1.54477544e+00, -1.52992804e+00, -1.51541045e+00,
#          -1.50120540e+00, -1.48729696e+00, -1.47367043e+00, -1.46031216e+00,
#          -1.44720951e+00, -1.43435071e+00, -1.42172480e+00, -1.40932155e+00,
#          -1.39713140e+00, -1.38514540e+00, -1.37335515e+00, -1.36175278e+00,
# ...

# %%
df.corr()
# Out:
#              User Rating   Reviews     Price      Year
# User Rating     1.000000 -0.001729 -0.133086  0.242383
# Reviews        -0.001729  1.000000 -0.109182  0.263560
# Price          -0.133086 -0.109182  1.000000 -0.153979
# Year            0.242383  0.263560 -0.153979  1.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
zx=stats.zscore(df['User Rating'])

# %%
sns.boxplot(y=df['User Rating'])
# Out:
# <AxesSubplot:ylabel='User Rating'>

# %%
stats.probplot(zx,dist='norm',plot=pylab)
# Out:
# ((array([-3.02105601e+00, -2.74159734e+00, -2.58463985e+00, -2.47343730e+00,
#          -2.38636226e+00, -2.31432444e+00, -2.25260787e+00, -2.19843901e+00,
#          -2.15004332e+00, -2.10621431e+00, -2.06609307e+00, -2.02904562e+00,
#          -1.99459017e+00, -1.96235173e+00, -1.93203245e+00, -1.90339171e+00,
#          -1.87623218e+00, -1.85039002e+00, -1.82572757e+00, -1.80212806e+00,
#          -1.77949153e+00, -1.75773174e+00, -1.73677374e+00, -1.71655195e+00,
#          -1.69700867e+00, -1.67809286e+00, -1.65975910e+00, -1.64196684e+00,
#          -1.62467968e+00, -1.60786485e+00, -1.59149272e+00, -1.57553639e+00,
#          -1.55997141e+00, -1.54477544e+00, -1.52992804e+00, -1.51541045e+00,
#          -1.50120540e+00, -1.48729696e+00, -1.47367043e+00, -1.46031216e+00,
#          -1.44720951e+00, -1.43435071e+00, -1.42172480e+00, -1.40932155e+00,
#          -1.39713140e+00, -1.38514540e+00, -1.37335515e+00, -1.36175278e+00,
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %%
# Books with their Genre
pd.DataFrame(df.groupby(['Name'])['Genre'].max())
# Out:
#                                                           Genre
# Name
# 10-Day Green Smoothie Cleanse                       Non Fiction
# 11/22/63: A Novel                                       Fiction
# 12 Rules for Life: An Antidote to Chaos             Non Fiction
# 1984 (Signet Classics)                                  Fiction
# 5,000 Awesome Facts (About Everything!) (Nation...  Non Fiction
# ...                                                         ...
# Winter of the World: Book Two of the Century Tr...      Fiction
# Women Food and God: An Unexpected Path to Almos...  Non Fiction
# Wonder                                                  Fiction
# Wrecking Ball (Diary of a Wimpy Kid Book 14)            Fiction
# You Are a Badass: How to Stop Doubting Your Gre...  Non Fiction
#
# [351 rows x 1 columns]

# %%
# Most Expensive Books 
df.iloc[np.where(df['Price']==105)]
# Out:
#                                                  Name  \
# 69  Diagnostic and Statistical Manual of Mental Di...
# 70  Diagnostic and Statistical Manual of Mental Di...
#
#                               Author  User Rating  Reviews  Price  Year  \
# 69  American Psychiatric Association          4.5     6679    105  2013
# 70  American Psychiatric Association          4.5     6679    105  2014
#
#           Genre
# 69  Non Fiction
# 70  Non Fiction

# %%
# Least Expesive books
df[df['Price']==0]
# Out:
#                                                   Name  \
# 42          Cabin Fever (Diary of a Wimpy Kid, Book 6)
# 71             Diary of a Wimpy Kid: Hard Luck, Book 8
# 116                        Frozen (Little Golden Book)
# 193                               JOURNEY TO THE ICE P
# 219                                  Little Blue Truck
# 358              The Constitution of the United States
# 381                                        The Getaway
# 461  The Short Second Life of Bree Tanner: An Eclip...
# 505                              To Kill a Mockingbird
# 506                              To Kill a Mockingbird
# 507                              To Kill a Mockingbird
# 508                              To Kill a Mockingbird
#
#                                Author  User Rating  Reviews  Price  Year  \
# 42                        Jeff Kinney          4.8     4505      0  2011
# 71                        Jeff Kinney          4.8     6812      0  2013
# ...

# %%
a=df['Genre'].value_counts()

# %%
a.plot.pie(autopct='%.1f%%',figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='Genre'>

# %%
# Rating Frequency
df['User Rating'].value_counts()
# Out:
# 4.8    127
# 4.7    108
# 4.6    105
# 4.5     60
# 4.9     52
# 4.4     38
# 4.3     25
# 4.0     14
# 4.2      8
# 4.1      6
# 3.9      3
# 3.8      2
# 3.3      1
# 3.6      1
# Name: User Rating, dtype: int64

# %%
# insight
# How many Fiction and and Non-Fiction books has been Published in Each Year
df.groupby(['Year'])['Genre'].value_counts()
# Out:
# Year  Genre
# 2009  Non Fiction    26
#       Fiction        24
# 2010  Non Fiction    30
#       Fiction        20
# 2011  Non Fiction    29
#       Fiction        21
# 2012  Non Fiction    29
#       Fiction        21
# 2013  Non Fiction    26
#       Fiction        24
# 2014  Fiction        29
#       Non Fiction    21
# 2015  Non Fiction    33
#       Fiction        17
# 2016  Non Fiction    31
#       Fiction        19
# 2017  Non Fiction    26
#       Fiction        24
# 2018  Non Fiction    29
#       Fiction        21
# 2019  Non Fiction    30
#       Fiction        20
# Name: Genre, dtype: int64

# %%
# Ratings with their Genres
df.groupby(['Genre'])['User Rating'].value_counts()
# Out:
# Genre        User Rating
# Fiction      4.8            76
#              4.9            41
#              4.7            34
#              4.6            31
#              4.5            18
#              4.3            11
#              4.4            10
#              4.0             5
#              4.1             4
#              3.9             3
#              4.2             3
#              3.8             2
#              3.3             1
#              3.6             1
# Non Fiction  4.6            74
#              4.7            74
#              4.8            51
#              4.5            42
#              4.4            28
#              4.3            14
#              4.9            11
#              4.0             9
#              4.2             5
#              4.1             2
# Name: User Rating, dtype: int64

# %%
# Ratings with their Genres
df.groupby(['Genre','Year'])['User Rating'].value_counts()
# Out:
# Genre        Year  User Rating
# Fiction      2009  4.7            7
#                    4.8            6
#                    4.6            5
#                    4.2            2
#                    4.4            2
#                                  ..
# Non Fiction  2019  4.7            6
#                    4.3            2
#                    4.4            1
#                    4.5            1
#                    4.9            1
# Name: User Rating, Length: 165, dtype: int64

# %%
df['Year'].value_counts()
# Out:
# 2009    50
# 2010    50
# 2011    50
# 2012    50
# 2013    50
# 2014    50
# 2015    50
# 2016    50
# 2017    50
# 2018    50
# 2019    50
# Name: Year, dtype: int64

# %%
# Non-Fiction Books
xx=pd.DataFrame(df.iloc[np.where(df['Genre']=='Non Fiction')])

# %%
xx
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 2              12 Rules for Life: An Antidote to Chaos
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 8        A Higher Loyalty: Truth, Lies, and Leadership
# 11   A Patriot's History of the United States: From...
# ..                                                 ...
# 539  Women Food and God: An Unexpected Path to Almo...
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# ...

# %%
ax=xx['User Rating'].value_counts()

# %%
# insight 1
# ratings on pie chart 
ax.plot.pie(autopct='%.1f%%',figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='User Rating'>

# %%
len(xx['Author'].unique())
# Out:
# 159

# %%
# insight 2
# Ratings with their number of books
xx.groupby(['User Rating'])['User Rating'].value_counts()
# Out:
# User Rating  User Rating
# 4.0          4.0             9
# 4.1          4.1             2
# 4.2          4.2             5
# 4.3          4.3            14
# 4.4          4.4            28
# 4.5          4.5            42
# 4.6          4.6            74
# 4.7          4.7            74
# 4.8          4.8            51
# 4.9          4.9            11
# Name: User Rating, dtype: int64

# %%
# insight 3 Might be Wrong Insight
# Authors with their Latest books According to the Data
pd.DataFrame(xx.groupby(['Name','Author'])['Year'].max())
# Out:
#                                                                                      Year
# Name                                               Author
# 10-Day Green Smoothie Cleanse                      JJ Smith                          2016
# 12 Rules for Life: An Antidote to Chaos            Jordan B. Peterson                2018
# 5,000 Awesome Facts (About Everything!) (Nation... National Geographic Kids          2019
# A Higher Loyalty: Truth, Lies, and Leadership      James Comey                       2018
# A Patriot's History of the United States: From ... Larry Schweikart                  2010
# ...                                                                                   ...
# When Breath Becomes Air                            Paul Kalanithi                    2016
# Whose Boat Is This Boat?: Comments That Don't H... The Staff of The Late Show with
#   2018
# Wild: From Lost to Found on the Pacific Crest T... Cheryl Strayed                    2012
# ...

# %%
cc=xx['Year'].value_counts()
print(cc)
cc.plot.pie(autopct='%.1f%%')
# Out:
# 2015    33
# 2016    31
# 2010    30
# 2019    30
# 2011    29
# 2012    29
# 2018    29
# 2009    26
# 2013    26
# 2017    26
# 2014    21
# Name: Year, dtype: int64
# <AxesSubplot:ylabel='Year'>

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.histplot(xx['Year'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Count'>

# %%
# insight 4
# Authors with their Max Rating books According to the Data
pd.DataFrame(xx.groupby(['Name','Author'])['User Rating'].max())
# Out:
#                                                                                      User Rating
# Name                                               Author
# 10-Day Green Smoothie Cleanse                      JJ Smith                                  4.7
# 12 Rules for Life: An Antidote to Chaos            Jordan B. Peterson                        4.7
# 5,000 Awesome Facts (About Everything!) (Nation... National Geographic Kids                  4.8
# A Higher Loyalty: Truth, Lies, and Leadership      James Comey                               4.7
# A Patriot's History of the United States: From ... Larry Schweikart                          4.6
# ...                                                                                          ...
# When Breath Becomes Air                            Paul Kalanithi                            4.8
# Whose Boat Is This Boat?: Comments That Don't H... The Staff of The Late Show with
#           4.6
# ...

# %%
xx.iloc[np.where(xx['Author']=='Jen Sincero')]['Name']
# Out:
# 546    You Are a Badass: How to Stop Doubting Your Gr...
# 547    You Are a Badass: How to Stop Doubting Your Gr...
# 548    You Are a Badass: How to Stop Doubting Your Gr...
# 549    You Are a Badass: How to Stop Doubting Your Gr...
# Name: Name, dtype: object

# %%
# insight 
# all Fiction books
zz=pd.DataFrame(df.iloc[np.where(df['Genre']=='Fiction')])
zz
# Out:
#                                                   Name               Author  \
# 1                                    11/22/63: A Novel         Stephen King
# 3                               1984 (Signet Classics)        George Orwell
# 5        A Dance with Dragons (A Song of Ice and Fire)  George R. R. Martin
# 6    A Game of Thrones / A Clash of Kings / A Storm...  George R. R. Martin
# 7                       A Gentleman in Moscow: A Novel          Amor Towles
# ..                                                 ...                  ...
# 541                                             Wonder        R. J. Palacio
# 542                                             Wonder        R. J. Palacio
# 543                                             Wonder        R. J. Palacio
# 544                                             Wonder        R. J. Palacio
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)          Jeff Kinney
#
#      User Rating  Reviews  Price  Year    Genre
# ...

# %%
gt=zz['User Rating'].value_counts()

# %%
# insight 
# ratings on pie chart of Fiction Books
gt.plot.pie(autopct='%.1f%%',figsize=(20,20))
# Out:
# <AxesSubplot:ylabel='User Rating'>

# %%
# insight 2
# Ratings with their number of books
zz.groupby(['User Rating'])['User Rating'].value_counts()
# Out:
# User Rating  User Rating
# 3.3          3.3             1
# 3.6          3.6             1
# 3.8          3.8             2
# 3.9          3.9             3
# 4.0          4.0             5
# 4.1          4.1             4
# 4.2          4.2             3
# 4.3          4.3            11
# 4.4          4.4            10
# 4.5          4.5            18
# 4.6          4.6            31
# 4.7          4.7            34
# 4.8          4.8            76
# 4.9          4.9            41
# Name: User Rating, dtype: int64

# %%
# insight 3                              Might be Wrong Insight
# Authors with their Latest books According to the Data
pd.DataFrame(zz.groupby(['Name','Author'])['Year'].agg('max','min'))
# Out:
#                                                                         Year
# Name                                               Author
# 11/22/63: A Novel                                  Stephen King         2011
# 1984 (Signet Classics)                             George Orwell        2017
# A Dance with Dragons (A Song of Ice and Fire)      George R. R. Martin  2011
# A Game of Thrones / A Clash of Kings / A Storm ... George R. R. Martin  2014
# A Gentleman in Moscow: A Novel                     Amor Towles          2017
# ...                                                                      ...
# Where the Crawdads Sing                            Delia Owens          2019
# Where the Wild Things Are                          Maurice Sendak       2009
# Winter of the World: Book Two of the Century Tr... Ken Follett          2012
# Wonder                                             R. J. Palacio        2017
# ...

# %%
df.iloc[np.where(df['Author']=='Stephen King')]
# Out:
#                           Name        Author  User Rating  Reviews  Price  \
# 1            11/22/63: A Novel  Stephen King          4.6     2052     22
# 79       Doctor Sleep: A Novel  Stephen King          4.7    15845     13
# 194  Joyland (Hard Case Crime)  Stephen King          4.5     4748     12
# 520    Under the Dome: A Novel  Stephen King          4.3     6740     20
#
#      Year    Genre
# 1    2011  Fiction
# 79   2013  Fiction
# 194  2013  Fiction
# 520  2009  Fiction

# %%
qq=zz['Year'].value_counts()
print(qq)
qq.plot.pie(autopct='%.1f%%')
# Out:
# 2014    29
# 2009    24
# 2013    24
# 2017    24
# 2011    21
# 2012    21
# 2018    21
# 2010    20
# 2019    20
# 2016    19
# 2015    17
# Name: Year, dtype: int64
# <AxesSubplot:ylabel='Year'>

# %%
# insight 4
# Authors with their Max Rating books According to the Data
pd.DataFrame(xx.groupby(['Name','Author'])['User Rating'].max())
# Out:
#                                                                                      User Rating
# Name                                               Author
# 10-Day Green Smoothie Cleanse                      JJ Smith                                  4.7
# 12 Rules for Life: An Antidote to Chaos            Jordan B. Peterson                        4.7
# 5,000 Awesome Facts (About Everything!) (Nation... National Geographic Kids                  4.8
# A Higher Loyalty: Truth, Lies, and Leadership      James Comey                               4.7
# A Patriot's History of the United States: From ... Larry Schweikart                          4.6
# ...                                                                                          ...
# When Breath Becomes Air                            Paul Kalanithi                            4.8
# Whose Boat Is This Boat?: Comments That Don't H... The Staff of The Late Show with
#           4.6
# ...

# %%
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %%
sns.relplot(x='User Rating',y='Price',data=df)

# %%
books =df.groupby(['Name', 'Author', 'Genre'], as_index=False)['Price'].\
mean().sort_values('Price', ascending=False).head(10)

books
# Out:
#                                                   Name  \
# 56   Diagnostic and Statistical Manual of Mental Di...
# 307                       The Twilight Saga Collection
# 112                           Hamilton: The Revolution
# 228  The Book of Basketball: The NBA According to T...
# 115         Harry Potter Paperback Box Set (Books 1-7)
# 191  Publication Manual of the American Psychologic...
# 333                                           Watchmen
# 281                       The Official SAT Study Guide
# 220                                      The Alchemist
# 282  The Official SAT Study Guide, 2016 Edition (Of...
#
#                                  Author        Genre  Price
# 56     American Psychiatric Association  Non Fiction  105.0
# 307                     Stephenie Meyer      Fiction   82.0
# 112                  Lin-Manuel Miranda  Non Fiction   54.0
# 228                        Bill Simmons  Non Fiction   53.0
# ...

# %%
book_by_year = df.groupby('Genre')
years = range(2009,2020)

non_fiction = book_by_year.get_group(("Non Fiction"))
non_fict = non_fiction.groupby('Year')['Name'].count().values

fiction = book_by_year.get_group("Fiction")
fict = fiction.groupby('Year')['Name'].count().values


figure, ax = plt.subplots(figsize=(12,9))

plt.plot(years,non_fict,  'o--', label='Non Fiction Bestsellers')
plt.plot(years,fict, 's--', label='Fiction Bestsellers')
plt.title('Number Of Bestsellers By Each Year')
plt.xlabel('Years')
plt.ylabel('Number Of Bestsellers')
plt.legend()
plt.show()

# %%
sns.countplot(df['Genre'])
# Out:
# C:\Users\yashw\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Genre', ylabel='count'>

# %%
stats.probplot(df['Reviews'],dist='norm',plot=pylab)
# Out:
# ((array([-3.02105601e+00, -2.74159734e+00, -2.58463985e+00, -2.47343730e+00,
#          -2.38636226e+00, -2.31432444e+00, -2.25260787e+00, -2.19843901e+00,
#          -2.15004332e+00, -2.10621431e+00, -2.06609307e+00, -2.02904562e+00,
#          -1.99459017e+00, -1.96235173e+00, -1.93203245e+00, -1.90339171e+00,
#          -1.87623218e+00, -1.85039002e+00, -1.82572757e+00, -1.80212806e+00,
#          -1.77949153e+00, -1.75773174e+00, -1.73677374e+00, -1.71655195e+00,
#          -1.69700867e+00, -1.67809286e+00, -1.65975910e+00, -1.64196684e+00,
#          -1.62467968e+00, -1.60786485e+00, -1.59149272e+00, -1.57553639e+00,
#          -1.55997141e+00, -1.54477544e+00, -1.52992804e+00, -1.51541045e+00,
#          -1.50120540e+00, -1.48729696e+00, -1.47367043e+00, -1.46031216e+00,
#          -1.44720951e+00, -1.43435071e+00, -1.42172480e+00, -1.40932155e+00,
#          -1.39713140e+00, -1.38514540e+00, -1.37335515e+00, -1.36175278e+00,
# ...

# %%
sns.distplot(df['Reviews'])
# Out:
# C:\Users\yashw\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Reviews', ylabel='Density'>

# %%
 # r=pandas_profiling.ProfileReport(df,title='Pandas Report')

# %%
df.iloc[fiction.groupby('Year')['Name'].count().values]
# Out:
#                                               Name              Author  \
# 24                        And the Mountains Echoed     Khaled Hosseini
# 20                     All the Light We Cannot See       Anthony Doerr
# 21                     All the Light We Cannot See       Anthony Doerr
# 21                     All the Light We Cannot See       Anthony Doerr
# 24                        And the Mountains Echoed     Khaled Hosseini
# 29        Balance (Angie's Extreme Stress Menders)         Angie Grace
# 17  Adult Coloring Book: Stress Relieving Patterns  Blue Star Coloring
# 19                              Alexander Hamilton         Ron Chernow
# 24                        And the Mountains Echoed     Khaled Hosseini
# 21                     All the Light We Cannot See       Anthony Doerr
# 20                     All the Light We Cannot See       Anthony Doerr
#
#     User Rating  Reviews  Price  Year        Genre
# 24          4.3    12159     13  2013      Fiction
# ...
